# %% [markdown]
# #INTRODUCCION A COMNADOS

# %% [markdown]
# ## Comando para python %python

# %%
Message = "Hello World"
print(Message)

# %% [markdown]
# ## Comando para sql %sql

# %%
# %sql
select "Hola"

# %% [markdown]
# ## Comando para R %r

# %%
# %r
print ("Hola Mundo")

# %% [markdown]
# ## Comando para Scala %scala

# %%
# %scala
var msg = "Hola Mundo"
print (msg)

# %% [markdown]
# ## Comando para sistema de archivos %nf

# %%
# %fs
ls

# %% [markdown]
# Comando para linux %sh

# %%
# %sh
ps

# %% [markdown]
# Comandos magicos de python

# %%
# %lsmagic

# %% [markdown]
# ## Conocer sintaxis de comandos

# %%
# %env?

# %%
# %ls?
