# %%
dbutils.widgets.text("p_file_date", "2024-12-30")
dbutils.widgets.text("p_environment", "developer")
date_run = dbutils.widgets.get("p_file_date")
environment = dbutils.widgets.get("p_environment")

# %%
v_result = (dbutils.notebook.run("01.Ingestion_file_movie_csv", 0, {"environment": environment, "date_run": date_run}))

# %%
v_result

# %%
v_result = (dbutils.notebook.run("02.Ingestion_file_language_csv", 0, {"p_environment": "developer","p_file_date": "2024-12-30"}))

# %%
v_result

# %%
v_result = (dbutils.notebook.run("03.Ingestion_file_genre_csv", 0, {"p_environment": "developer","p_file_date": "2024-12-30"}))

# %%
v_result

# %%
v_result = (dbutils.notebook.run("04.Ingestion_file_country_json", 0, {"p_environment": "developer","p_file_date": "2024-12-30"}))

# %%
v_result

# %%
v_result = (dbutils.notebook.run("05.Ingestion_file_person_json", 0, {"p_environment": "developer","p_file_date": "2024-12-30"}))

# %%
v_result

# %%
v_result = (dbutils.notebook.run("06.Ingestion_file_movie_genre_json",0, {"p_environment": "developer","p_file_date": "2024-12-30"}))

# %%
v_result

# %%
v_result = (dbutils.notebook.run("07.Ingestion_file_movie_cast_json",0, {"p_environment": "developer","p_file_date": "2024-12-30"}))

# %%
v_result

# %%
v_result = (dbutils.notebook.run("08.Ingestion_file_lenguage_role_json",0, {"p_environment": "developer","p_file_date": "2024-12-30"}))

# %%
v_result

# %%
v_result = (dbutils.notebook.run("09.Ingestion_file_production_comp_multi_csv",0, {"p_environment": "developer","p_file_date": "2024-12-30"}))

# %%
v_result

# %%
v_result = (dbutils.notebook.run("10.Ingestion_file_movie_comp_multi_csv",0, {"p_environment": "developer","p_file_date": "2024-12-30"}))

# %%
v_result

# %%
v_result =  (dbutils.notebook.run("11.Ingestion_file_movie_leng_multi_json",0, {"p_environment": "developer","p_file_date": "2024-12-30"}))

# %%
v_result

# %%
v_result = (dbutils.notebook.run("12.Ingestion_file_production_comp_multi_json",0, {"p_environment": "developer", "p_file_date": "2024-12-30"}))

# %%
v_result
